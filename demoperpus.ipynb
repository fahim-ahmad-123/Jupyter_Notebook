# %%
d=int(input('enter the distance'))
t=int(input('enter the time'))
spedd=d/t
# Out:
# enter the distance 33.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 d=int(input('enter the distance'))
#       2 t=int(input('enter the time'))
#       3 spedd=d/t
#
# ValueError: invalid literal for int() with base 10: '33.5'

# %%
d=float(input('enter the distance'))
t=float(input('enter the time'))
speed=d/t
speed
# Out:
# enter the distance 45
# enter the time 5
# 9.0

# %%
x=input('enter the distance')
t=input('enter the distance')
d=0
if x.isnumeric():
    d=float(x)
    if t.isnumeric():
        t=float(t)
    elif t<0:
        print('erorr:time can not negative')
    elif (x>0 or x<0) and t==0 :
        print('erorr:time cant not zero')
    elif t==0:
        print('un defined')
    d=float(x)
    time=float(t)
    speed=d/t
    print(speed)
elif x.isalpha():
    print('erorr:it alpha value')
elif x.isalnum():
    print('erorr:it alpha numeric')
# Out:
# enter the distance 45
# enter the distance 5
# 9.0

# %%
import os
os.path.abspath("demoperpus.ipynb")
# Out:
# 'C:\\Users\\dell\\demoperpus.ipynb'

# %%
print ('hello')
